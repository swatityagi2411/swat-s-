# %% [markdown]
# **Basic API CAll**

# %%
import json
import urllib.request as url
import pandas as pd
path = "https://data.covid19india.org/v4/min/data.min.json"
response=url.urlopen(path)
data=json.load(response)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['AN', 'AP', 'AR', 'AS', 'BR', 'CH', 'CT', 'DL', 'DN', 'GA', 'GJ', 'HP', 'HR', 'JH', 'JK', 'KA', 'KL', 'LA', 'LD', 'MH', 'ML', 'MN', 'MP', 'MZ', 'NL', 'OR', 'PB', 'PY', 'RJ', 'SK', 'TG', 'TN', 'TR', 'TT', 'UP', 'UT', 'WB'])

# %%
delhi=data['DL']

# %%
df=pd.DataFrame(delhi)
df.head()
# Out:
#                delta  delta21_14    delta7 districts  \
# confirmed       45.0       195.0     267.0       NaN
# recovered       46.0         NaN     239.0       NaN
# tested       56751.0         NaN  395086.0       NaN
# vaccinated1  12482.0         NaN  160323.0       NaN
# vaccinated2  11839.0         NaN  269146.0       NaN
#
#                                                           meta       total
# confirmed                                                  NaN   1439870.0
# recovered                                                  NaN   1414431.0
# tested       {'date': '2021-10-31', 'source': 'https://t.me...  29427753.0
# vaccinated1                                                NaN  13055636.0
# vaccinated2                                                NaN   7425404.0

# %% [markdown]
# **TWITTER API CALL**

# %%
import tweepy
import pandas as pd

# %%
consumer_key="RdoJsmzm5kRwwyDG6lcmCLsyN "
consumer_secret="hlkKsAaG5Niu7mzk7e8eu33Q34Zbs24axypaexZhgci4TYAFkg "
access_token="1478780282346086410-ihJ8ugtVDRExUIKwqjh9bkgmMg38uM "
access_secret="3qQCJyfyVqwSbOE5VflqU8lp3VCVddk2RcYwgysoyx5Cl"

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api=tweepy.API(auth)

# %%
search="#msdhoni"
data_since="2022-04-15"

# %%
tweets=tweepy.Cursor(api.search_tweets, q=search, since=data_since).items(5)

# %%
type(tweets)
# Out:
# tweepy.cursor.ItemIterator

# %%
for twt in tweets:
  print(twt)
# Out:
# WARNING:tweepy.api:Unexpected parameter: since
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-8-c648fb328e1f> in <cell line: 1>()
# ----> 1 for twt in tweets:
#       2   print(twt)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# ...

# %%
map(  )
