# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-eab76087-b008-4316-abcf-03f871a2b4df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eab76087-b008-4316-abcf-03f871a2b4df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Studentdata (1).csv')

# %%
df.shape
# Out:
# (256, 25)

# %%
df.head()
# Out:
#    Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 0           0     Male            Third    CSE/IT
# 1           1   Female           Second      CSIT
# 2           2     Male           Second      CSIT
# 3           3     Male           Second      CSIT
# 4           4     Male           Second      CSIT
#
#   1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 0                      Normal Schooling               >=80% and <90%
# 1               Schooling with Tuitions                       >= 90%
# 2                      Normal Schooling                       >= 90%
# 3                      Normal Schooling               >=70% and <80%
# 4                      Normal Schooling               >=70% and <80%
#
#   3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 0                              Town                     Normal Schooling
# 1                              City              Schooling with Tuitions
# ...

# %%
pd.value_counts(df['2.Gender'])
# Out:
# Male      191
# Female     65
# Name: 2.Gender, dtype: int64

# %%
pd.value_counts(df['3. Year of Study'])
# Out:
# Second    198
# First      45
# Third      13
# Name: 3. Year of Study, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,MinMaxScaler

# %%
Gender_label=LabelEncoder()
df['2.Gender']=Gender_label.fit_transform(df['2.Gender'])

# %%
Year_label=LabelEncoder()
df['3. Year of Study']=Year_label.fit_transform(df['3. Year of Study'])
Branch_label=LabelEncoder()
df['4. Branch']=Branch_label.fit_transform(df['4. Branch'])

# %%
Schooltype_label=LabelEncoder()
df['1. Type of Schooling till 10th Grade:']=Schooltype_label.fit_transform(df['1. Type of Schooling till 10th Grade:'])
